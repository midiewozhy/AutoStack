# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold

# %%
X, y = np.ones((100,2)), np.zeros(100)

# %%
kf = KFold(5)

# %%
split = kf.split(X)

# %%
df = pd.DataFrame(index = range(y.shape[0]), columns = ['a', 'b'])

# %%
for (train_idx, test_idx) in split:
    df.loc[test_idx, 'a'] = test_idx

# %%
df
# Out:
#      a    b
# 0    0  NaN
# 1    1  NaN
# 2    2  NaN
# 3    3  NaN
# 4    4  NaN
# ..  ..  ...
# 95  95  NaN
# 96  96  NaN
# 97  97  NaN
# 98  98  NaN
# 99  99  NaN
#
# [100 rows x 2 columns]
